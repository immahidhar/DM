# %%
import pandas
import matplotlib.pyplot as plt

# %% [markdown]
# # RFM output

# %%
rfmOutput = pandas.read_csv("RFM_output.csv")
rfmOutput
# Out:
#      CustomerID  UnitPrice  Recency  Frequency  DaysBtwVisit  r_quartile  \
# 0       12346.0       2.08      347     148430      0.000000           1
# 1       12347.0     481.21       24       2458      1.738889           3
# 2       12348.0     178.71       97       2341      8.379310           2
# 3       12349.0     605.10       40        631      0.000000           3
# 4       12350.0      65.30      332        197      0.000000           1
# ...         ...        ...      ...        ...           ...         ...
# 8077    C578097      25.99       39        324      0.000000           3
# 8078    C579757       0.65       31         24      0.000000           3
# 8079    C579907       7.65       30          2      0.000000           3
# 8080    C580604   11586.50       26          1      0.000000           3
# 8081    C580605   17836.46       26          1      0.000000           3
#
#       f_quartile  m_quartile  RFM_Score                    Segment
# ...

# %%
rfmOutput.Segment.value_counts()
# Out:
# Churned Customers            2674
# At Risk Customers            2614
# Potential Loyal Customers    1750
# New Customers                1028
# Best Customers                 16
# Name: Segment, dtype: int64

# %%
segment = rfmOutput[rfmOutput['Segment'] == 'Churned Customers']
unitPrice = segment['UnitPrice']
recency = segment['Recency']
frequency = segment['Frequency']
daysBtwVisit = segment['DaysBtwVisit']
data = [recency, frequency, unitPrice, daysBtwVisit]
fig = plt.figure(figsize=(10,2))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data, vert=0)
ax.set_yticklabels(['Recency', 'Frequency', 'Unit Price', 'DaysBtwVisit'])
plt.xlim(-5, 400)
plt.title('RFM - Churned Customers box plot') 
plt.show()

# %%
segment = rfmOutput[rfmOutput['Segment'] == 'At Risk Customers']
unitPrice = segment['UnitPrice']
recency = segment['Recency']
frequency = segment['Frequency']
daysBtwVisit = segment['DaysBtwVisit']
data = [recency, frequency, unitPrice, daysBtwVisit]
fig = plt.figure(figsize=(10,2))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data, vert=0)
ax.set_yticklabels(['Recency', 'Frequency', 'Unit Price', 'DaysBtwVisit'])
plt.xlim(-10, 1200)
plt.title('RFM - At Risk Customers box plot') 
plt.show()

# %%
segment = rfmOutput[rfmOutput['Segment'] == 'Potential Loyal Customers']
unitPrice = segment['UnitPrice']
recency = segment['Recency']
frequency = segment['Frequency']
daysBtwVisit = segment['DaysBtwVisit']
data = [recency, frequency, unitPrice, daysBtwVisit]
fig = plt.figure(figsize=(10,2))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data, vert=0)
ax.set_yticklabels(['Recency', 'Frequency', 'Unit Price', 'DaysBtwVisit'])
plt.xlim(-50, 4400)
plt.title('RFM - Potential Loyal Customers box plot') 
plt.show()

# %%
segment = rfmOutput[rfmOutput['Segment'] == 'New Customers']
unitPrice = segment['UnitPrice']
recency = segment['Recency']
frequency = segment['Frequency']
daysBtwVisit = segment['DaysBtwVisit']
data = [recency, frequency, unitPrice, daysBtwVisit]
fig = plt.figure(figsize=(10,2))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data, vert=0)
ax.set_yticklabels(['Recency', 'Frequency', 'Unit Price', 'DaysBtwVisit'])
plt.xlim(-10, 1100)
plt.title('RFM - New Customers box plot') 
plt.show()

# %%
segment = rfmOutput[rfmOutput['Segment'] == 'Best Customers']
unitPrice = segment['UnitPrice']
recency = segment['Recency']
frequency = segment['Frequency']
daysBtwVisit = segment['DaysBtwVisit']
data = [recency, frequency, unitPrice, daysBtwVisit]
fig = plt.figure(figsize=(10,2))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data, vert=0)
ax.set_yticklabels(['Recency', 'Frequency', 'Unit Price', 'DaysBtwVisit'])
plt.xlim(-100, 12000)
plt.title('RFM - Best Customers box plot') 
plt.show()

# %% [markdown]
# # KMeans output

# %%
kmeansOutput = pandas.read_csv("kmeans_output.csv")
kmeansOutput
# Out:
#      CustomerID  UnitPrice  Recency  Frequency  DaysBtwVisit  Segment
# 0       12346.0       2.08      347     148430      0.000000        2
# 1       12347.0     481.21       24       2458      1.738889        0
# 2       12348.0     178.71       97       2341      8.379310        0
# 3       12349.0     605.10       40        631      0.000000        0
# 4       12350.0      65.30      332        197      0.000000        3
# ...         ...        ...      ...        ...           ...      ...
# 8077    C578097      25.99       39        324      0.000000        0
# 8078    C579757       0.65       31         24      0.000000        0
# 8079    C579907       7.65       30          2      0.000000        0
# 8080    C580604   11586.50       26          1      0.000000        1
# 8081    C580605   17836.46       26          1      0.000000        1
#
# [8082 rows x 6 columns]

# %%
kmeansOutput.Segment.value_counts()
# Out:
# 0    4856
# 3    3182
# 1      17
# 4      16
# 2      11
# Name: Segment, dtype: int64

# %%
segment = kmeansOutput[kmeansOutput['Segment'] == 1]
unitPrice = segment['UnitPrice']
recency = segment['Recency']
frequency = segment['Frequency']
daysBtwVisit = segment['DaysBtwVisit']
data = [recency, frequency, unitPrice, daysBtwVisit]
fig = plt.figure(figsize=(10,2))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data, vert=0)
ax.set_yticklabels(['Recency', 'Frequency', 'Unit Price', 'DaysBtwVisit'])
plt.xlim(-10, 2200)
plt.title('KMeans - Segment 1 box plot') 
plt.show()

# %%
segment = kmeansOutput[kmeansOutput['Segment'] == 0]
unitPrice = segment['UnitPrice']
recency = segment['Recency']
frequency = segment['Frequency']
daysBtwVisit = segment['DaysBtwVisit']
data = [recency, frequency, unitPrice, daysBtwVisit]
fig = plt.figure(figsize=(10,2))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data, vert=0)
ax.set_yticklabels(['Recency', 'Frequency', 'Unit Price', 'DaysBtwVisit'])
plt.xlim(-5, 500)
plt.title('KMeans - Segment 0 box plot') 
plt.show()

# %%
segment = kmeansOutput[kmeansOutput['Segment'] == 3]
unitPrice = segment['UnitPrice']
recency = segment['Recency']
frequency = segment['Frequency']
daysBtwVisit = segment['DaysBtwVisit']
data = [recency, frequency, unitPrice, daysBtwVisit]
fig = plt.figure(figsize=(10,2))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data, vert=0)
ax.set_yticklabels(['Recency', 'Frequency', 'Unit Price', 'DaysBtwVisit'])
plt.xlim(-100, 30000)
plt.title('KMeans - Segment 3 box plot') 
plt.show()

# %%
segment = kmeansOutput[kmeansOutput['Segment'] == 2]
unitPrice = segment['UnitPrice']
recency = segment['Recency']
frequency = segment['Frequency']
daysBtwVisit = segment['DaysBtwVisit']
data = [recency, frequency, unitPrice, daysBtwVisit]
fig = plt.figure(figsize=(10,2))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data, vert=0)
ax.set_yticklabels(['Recency', 'Frequency', 'Unit Price', 'DaysBtwVisit'])
plt.xlim(-20, 4000)
plt.title('KMeans - Segment 2 box plot') 
plt.show()

# %%
segment = kmeansOutput[kmeansOutput['Segment'] == 4]
unitPrice = segment['UnitPrice']
recency = segment['Recency']
frequency = segment['Frequency']
daysBtwVisit = segment['DaysBtwVisit']
data = [recency, frequency, unitPrice, daysBtwVisit]
fig = plt.figure(figsize=(10,2))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data, vert=0)
ax.set_yticklabels(['Recency', 'Frequency', 'Unit Price', 'DaysBtwVisit'])
plt.xlim(-1000, 165000)
plt.title('KMeans - Segment 4 box plot') 
plt.show()

# %% [markdown]
# # KMedoids output

# %%
kmedoidsOutput = pandas.read_csv("Kmedoids_output.csv")
kmedoidsOutput
# Out:
#      CustomerID  UnitPrice  Recency  Frequency  DaysBtwVisit  Segment
# 0       12346.0       2.08      347     148430      0.000000        3
# 1       12347.0     481.21       24       2458      1.738889        3
# 2       12348.0     178.71       97       2341      8.379310        1
# 3       12349.0     605.10       40        631      0.000000        3
# 4       12350.0      65.30      332        197      0.000000        2
# ...         ...        ...      ...        ...           ...      ...
# 8077    C578097      25.99       39        324      0.000000        1
# 8078    C579757       0.65       31         24      0.000000        1
# 8079    C579907       7.65       30          2      0.000000        1
# 8080    C580604   11586.50       26          1      0.000000        3
# 8081    C580605   17836.46       26          1      0.000000        3
#
# [8082 rows x 6 columns]

# %%
kmedoidsOutput.Segment.value_counts()
# Out:
# 1    3115
# 0    1513
# 4    1476
# 2    1034
# 3     944
# Name: Segment, dtype: int64

# %%
segment = kmedoidsOutput[kmedoidsOutput['Segment'] == 1]
unitPrice = segment['UnitPrice']
recency = segment['Recency']
frequency = segment['Frequency']
daysBtwVisit = segment['DaysBtwVisit']
data = [recency, frequency, unitPrice, daysBtwVisit]
fig = plt.figure(figsize=(10,2))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data, vert=0)
ax.set_yticklabels(['Recency', 'Frequency', 'Unit Price', 'DaysBtwVisit'])
plt.xlim(-100, 2500)
plt.title('KMedoids - Segment 1 box plot') 
plt.show()

# %%
segment = kmedoidsOutput[kmedoidsOutput['Segment'] == 0]
unitPrice = segment['UnitPrice']
recency = segment['Recency']
frequency = segment['Frequency']
daysBtwVisit = segment['DaysBtwVisit']
data = [recency, frequency, unitPrice, daysBtwVisit]
fig = plt.figure(figsize=(10,2))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data, vert=0)
ax.set_yticklabels(['Recency', 'Frequency', 'Unit Price', 'DaysBtwVisit'])
plt.xlim(-10, 800)
plt.title('KMedoids - Segment 0 box plot') 
plt.show()

# %%
segment = kmedoidsOutput[kmedoidsOutput['Segment'] == 3]
unitPrice = segment['UnitPrice']
recency = segment['Recency']
frequency = segment['Frequency']
daysBtwVisit = segment['DaysBtwVisit']
data = [recency, frequency, unitPrice, daysBtwVisit]
fig = plt.figure(figsize=(10,2))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data, vert=0)
ax.set_yticklabels(['Recency', 'Frequency', 'Unit Price', 'DaysBtwVisit'])
plt.xlim(-10, 450)
plt.title('KMedoids - Segment 3 box plot') 
plt.show()

# %%
segment = kmedoidsOutput[kmedoidsOutput['Segment'] == 4]
unitPrice = segment['UnitPrice']
recency = segment['Recency']
frequency = segment['Frequency']
daysBtwVisit = segment['DaysBtwVisit']
data = [recency, frequency, unitPrice, daysBtwVisit]
fig = plt.figure(figsize=(10,2))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data, vert=0)
ax.set_yticklabels(['Recency', 'Frequency', 'Unit Price', 'DaysBtwVisit'])
plt.xlim(-10, 900)
plt.title('KMedoids - Segment 4 box plot') 
plt.show()

# %%
segment = kmedoidsOutput[kmedoidsOutput['Segment'] == 2]
unitPrice = segment['UnitPrice']
recency = segment['Recency']
frequency = segment['Frequency']
daysBtwVisit = segment['DaysBtwVisit']
data = [recency, frequency, unitPrice, daysBtwVisit]
fig = plt.figure(figsize=(10,2))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data, vert=0)
ax.set_yticklabels(['Recency', 'Frequency', 'Unit Price', 'DaysBtwVisit'])
plt.xlim(-10, 400)
plt.title('KMedoids - Segment 2 box plot') 
plt.show()
